# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-1.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-1.2.0-py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.3/142.3 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-1.2.0

# %%
from groq import Groq

client = Groq(api_key="PASTE_YOUR_GROQ_API_KEY_HERE")

golfers = [
    "Scottie Scheffler",
    "Rory McIlroy",
    "Bryson DeChambeau",
    "Patrick Reed",
    "Sam Burns",
    "Colin Morikawa"
]

for golfer in golfers:
    prompt = f"Give me 3 short facts about professional golfer {golfer}."

    chat_completion = client.chat.completions.create(
        messages=[
            {"role": "user", "content": prompt}
        ],
        model="llama-3.3-70b-versatile"
    )

    print(f"\n--- {golfer} ---")
    print(chat_completion.choices[0].message.content)
# Out:
# --- Scottie Scheffler ---
# Here are three short facts about professional golfer Scottie Scheffler:
#
# 1. Scottie Scheffler is an American professional golfer who was born on June 21, 1996, in Ridgewood, New Jersey.
# 2. He won the 2022 Masters Tournament, which was his first major championship victory.
# 3. Scheffler reached the number one ranking in the Official World Golf Ranking in March 2022, following a series of impressive performances on the PGA Tour.
#
# --- Rory McIlroy ---
# Here are 3 short facts about Rory McIlroy:
#
# 1. Rory McIlroy was born on May 4, 1989, in Holywood, Northern Ireland.
# 2. He has won four major championships: the 2011 U.S. Open, the 2012 PGA Championship, and the 2014 Open Championship and PGA Championship.
# 3. McIlroy has been ranked as the world's number one golfer on multiple occasions, first achieving the ranking in 2012.
#
# --- Bryson DeChambeau ---
# Here are three short facts about Bryson DeChambeau:
#
# 1. Bryson DeChambeau is an American professional golfer who was born on September 16, 1993, in Modesto, California.
# 2. He is known for his unique approach to the game, using single-length irons and a distinctive swing style that he has developed through extensive research and experimentation.
# 3. DeChambeau has won several major tournaments, including the 2020 U.S. Open, where he claimed his first major victory by a six-stroke margin at Winged Foot Golf Club.
#
# --- Patrick Reed ---
# Here are three short facts about professional golfer Patrick Reed:
#
# 1. Patrick Reed, also known as "Captain America," is an American professional golfer who plays on the PGA Tour.
# 2. He won the 2018 Masters Tournament, his first major championship, by one stroke over Rickie Fowler.
# 3. Reed has represented the United States in several international team competitions, including the Ryder Cup and the Presidents Cup, earning a reputation as a strong team player.
#
# --- Sam Burns ---
# Here are three short facts about professional golfer Sam Burns:
#
# 1. Sam Burns is an American professional golfer who was born on July 23, 1996, in Shreveport, Louisiana.
# 2. He played college golf at Louisiana State University (LSU) and had a successful amateur career before turning pro in 2017.
# 3. Sam Burns has won multiple PGA Tour events, including the Valspar Championship and the Charles Schwab Challenge, and has also represented the United States in international team competitions.
#
# --- Colin Morikawa ---
# Here are three short facts about Colin Morikawa:
#
# 1. Colin Morikawa is an American professional golfer born on February 6, 1998, in Los Angeles, California.
# 2. Morikawa won the 2020 PGA Championship, his first major victory, at the age of 23, making him one of the youngest PGA Championship winners.
# 3. Morikawa played college golf at the University of California, Berkeley, where he won numerous awards and accolades, including the 2019 Hogan Award, before turning pro in 2019.
